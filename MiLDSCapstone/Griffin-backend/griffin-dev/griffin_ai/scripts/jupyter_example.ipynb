# %% [markdown]
# # Django Base Jupyter Notebook settings
#
# (must be executed from the root of the Django project)

# %%
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "griffin_ai.settings.dev.dse")
os.environ.setdefault("DJANGO_ALLOW_ASYNC_UNSAFE", "true")

# %%
from dotenv import load_dotenv
load_dotenv("griffin_ai/settings/dev/.env")

# %%
import django
django.setup()
